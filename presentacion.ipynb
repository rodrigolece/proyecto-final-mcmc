# %% [markdown]
# # Histéresis y avalanchas

# %% [markdown]
# ### Raúl Reyes (/raul_reyes)
# ### Rodrigo Leal (/rodrigolece)

# %% [markdown]
# Hamiltoniano:
#
# $$ H = - \sum_{\langle i, j \rangle} J s_i s_j - \sum_{i}(H(t) + h_i)s_i $$

# %% [markdown]
# El campo aleatorio se saca de la distribución:
#
# $$ P(h) =  \frac{1}{\sqrt{2 \pi} R} e^{-h^2/2R^2} $$

# %%
using PyPlot

# %%
using Histeresis

# %%
L = 50
N = L^2
m = edo_inicial(L)

@time mag, hs = magnetizacion_aumenta_H(m);
# Out:
# elapsed time: 0.546682142 seconds (27844524 bytes allocated)

# %%
figure(figsize=(7,5))
ylabel(L"M/N")
xlabel(L"H/J") #J=1
plot(hs,mag/N, ".");
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1135b4b50>)

# %% [markdown]
# Hacemos un zoom: ruido de Barkhausen

# %%
n = 1100

figure(figsize=(5,3))
xlabel(L"M/N")
ylabel(L"H/J") #J=1
plot(hs[n:end],(mag/N)[n:end],".");
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x113208610>)

# %% [markdown]
# ¿Cómo se ve la evolución del sistema?

# %%
L = 10
m = edo_inicial(L)
num_pasos = 50

@time edos = microEstados_aumenta_H(m, num_pasos);
# Out:
# elapsed time: 0.281080122 seconds (4898624 bytes allocated)

# %%
for estado in edos
    figure(figsize=(4,4))
    imshow(estado, interpolation="none")
end
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.py:412: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_num_figures`).
#   max_open_warning, RuntimeWarning)
# Figure(PyObject <matplotlib.figure.Figure object at 0x10f831650>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x10ff6f8d0>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x10fff09d0>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x110089310>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x1100eb650>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x110177c50>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x1101e7fd0>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x110277950>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x1102f1850>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x1103810d0>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x1103ee790>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x11047e110>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x110497290>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x11057b1d0>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x110608850>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x110679110>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x110703850>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x110775650>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x1107f7e90>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x110872e90>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x1109463d0>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x1109a8a50>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x110a42490>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x1102ba550>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x110b0db90>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x110b333d0>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x110c08850>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x110c95f90>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x110d07790>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x110d92ed0>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x110e04cd0>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x110e93550>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x110f0c550>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x110f9d450>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x111002ad0>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x111099510>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x111109c90>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x111199510>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x111207bd0>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x111297550>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x1112bb610>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x111394610>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x111420c90>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x111491550>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x111520c90>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x111591a90>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x11161f310>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x11166f950>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x1116fca50>)
# Figure(PyObject <matplotlib.figure.Figure object at 0x11176e890>)

# %% [markdown]
# ## Falta:
#
# - Hacer la simulación de regreso, cuando el campo disminuye
# - Hacer una animación de lo que mostramos con un `for`
# - Graficar el número de espines que cambia cada paso
# - Estudiar el tamaño de las avalanchas
